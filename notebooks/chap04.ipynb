# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
"""
I don't know how much I can really deviate from how the original chapter writes the codes, 
but I'll try and just explain my personal thought process. 
"""

jupyturtle.make_turtle() #I assume this is integral since you can't really move the turtle without one
jupyturtle.forward(100) #Self explanitory movement, but what really defines "100?" (I just read a little more and it's arbritrary)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward #This would need to be from instead of import because you're not specifically importing jupyturtle
#rather you're importing specific functions from jupyturtle

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,200.0,75.0) translate(200.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
# make_turtle()
# left(90)
# forward(20)
# left(20)
# forward(50)

"""
Square Attempt

4 sides of equal length so 'forward()' should be the same length everytime and if we start with 
'forward()' then we would have to make 3 left/right turns
since we already tried left above, lets try right.
"""
make_turtle()
forward(50)
right(90)
forward(50)
right(90)
forward(50)
right(90)
forward(50) # I see a potential function that could be made from this though
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="125.0" x2="150.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="125.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
"""
I'll just make it turn left this time
"""
make_turtle()
forward(50)
left(90)
forward(50)
left(90)
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(0.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    right(90) #runs these two lines 4 times, which is why the turtle actually turns one more time at the end
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="125.0" x2="150.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="125.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
    make_turtle()
    for i in range(4):
        forward(50)
        right(90)

# %% [markdown]
# Now we can call the function like this.

# %%
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="125.0" x2="150.0" y2="125.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="125.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(width):
    make_turtle()
    for i in range(4):
        forward(width)
        right(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
square(10)
square(25)
square(12)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="160.0" y2="85.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="85.0" x2="150.0" y2="85.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="85.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="175.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="75.0" x2="175.0" y2="100.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="100.0" x2="150.0" y2="100.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="100.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="162.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.0" y1="75.0" x2="162.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.0" y1="87.0" x2="150.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="87.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def polygon(n, width):
    make_turtle()
    angle = 360/n
    for i in range(n):
        forward(width)
        right(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="98.5" x2="192.0" y2="127.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="127.7" x2="165.0" y2="140.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="140.7" x2="138.0" y2="127.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="127.7" x2="131.3" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="98.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
#polygon(30, 2)

import math

def circle(radius):
    make_turtle(delay=0.02)
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference/n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
circle(30)

#There's two outputs here which is probably my fault for including make_turtle() in both of the commands, though I am curious why only one of them ran
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <g transform="rotate(-90.0,150,75) translate(150, 75)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="76.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="76.3" x2="168.2" y2="78.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="78.9" x2="173.3" y2="82.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="82.6" x2="177.5" y2="87.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="87.2" x2="180.6" y2="92.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="92.7" x2="182.5" y2="98.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="98.6" x2="183.2" y2="104.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="104.9" x2="182.5" y2="111.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="111.1" x2="180.6" y2="117.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="117.1" x2="177.5" y2="122.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="122.6" x2="173.3" y2="127.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="127.2" x2="168.2" y2="130.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="130.9" x2="162.4" y2="133.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="133.5" x2="156.3" y2="134.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="134.8" x2="150.0" y2="134.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="134.8" x2="143.9" y2="133.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="133.5" x2="138.1" y2="130.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="130.9" x2="133.0" y2="127.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="127.2" x2="128.8" y2="122.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="122.6" x2="125.7" y2="117.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="117.1" x2="123.7" y2="111.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="111.1" x2="123.1" y2="104.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="104.9" x2="123.7" y2="98.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="98.6" x2="125.7" y2="92.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="92.7" x2="128.8" y2="87.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="87.2" x2="133.0" y2="82.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="82.6" x2="138.1" y2="78.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="78.9" x2="143.9" y2="76.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="76.3" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        right(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360/n
    polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle/360 
    n = 30
    length = arc_length/n
    step_angle = angle/n
    polyline(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius, 360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay = 0)
circle(20)
polyline(2, 30, 0)
arc(35, 90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="154.2" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="75.0" x2="158.3" y2="75.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.3" y1="75.9" x2="162.1" y2="77.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="77.6" x2="165.5" y2="80.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.5" y1="80.0" x2="168.3" y2="83.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.3" y1="83.1" x2="170.4" y2="86.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.4" y1="86.8" x2="171.7" y2="90.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.7" y1="90.8" x2="172.1" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.1" y1="94.9" x2="171.7" y2="99.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.7" y1="99.1" x2="170.4" y2="103.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.4" y1="103.1" x2="168.3" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.3" y1="106.7" x2="165.5" y2="109.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.5" y1="109.8" x2="162.1" y2="112.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="112.3" x2="158.3" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.3" y1="114.0" x2="154.2" y2="114.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="114.9" x2="150.0" y2="114.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="114.9" x2="145.9" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.9" y1="114.0" x2="142.1" y2="112.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.1" y1="112.3" x2="138.7" y2="109.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.7" y1="109.8" x2="135.9" y2="106.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="106.7" x2="133.8" y2="103.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.8" y1="103.1" x2="132.5" y2="99.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.5" y1="99.1" x2="132.1" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.1" y1="94.9" x2="132.5" y2="90.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.5" y1="90.8" x2="133.8" y2="86.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.8" y1="86.8" x2="135.9" y2="83.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="83.1" x2="138.7" y2="80.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.7" y1="80.0" x2="142.1" y2="77.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.1" y1="77.6" x2="145.9" y2="75.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.9" y1="75.9" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="211.8" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.8" y1="75.0" x2="213.7" y2="75.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.7" y1="75.1" x2="215.5" y2="75.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.5" y1="75.3" x2="217.3" y2="75.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.3" y1="75.6" x2="219.1" y2="76.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.1" y1="76.0" x2="220.9" y2="76.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.9" y1="76.4" x2="222.6" y2="77.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="222.6" y1="77.0" x2="224.3" y2="77.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="224.3" y1="77.7" x2="226.0" y2="78.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="226.0" y1="78.4" x2="227.6" y2="79.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="227.6" y1="79.2" x2="229.2" y2="80.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.2" y1="80.1" x2="230.7" y2="81.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.7" y1="81.1" x2="232.2" y2="82.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.2" y1="82.2" x2="233.6" y2="83.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.6" y1="83.4" x2="235.0" y2="84.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.0" y1="84.6" x2="236.3" y2="85.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="236.3" y1="85.9" x2="237.5" y2="87.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="237.5" y1="87.3" x2="238.7" y2="88.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.7" y1="88.7" x2="239.8" y2="90.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="239.8" y1="90.2" x2="240.8" y2="91.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="240.8" y1="91.7" x2="241.7" y2="93.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="241.7" y1="93.3" x2="242.5" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="242.5" y1="94.9" x2="243.3" y2="96.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="243.3" y1="96.6" x2="243.9" y2="98.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="243.9" y1="98.3" x2="244.5" y2="100.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="244.5" y1="100.1" x2="245.0" y2="101.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="245.0" y1="101.8" x2="245.3" y2="103.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="245.3" y1="103.6" x2="245.6" y2="105.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="245.6" y1="105.4" x2="245.8" y2="107.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="245.8" y1="107.2" x2="245.9" y2="109.1"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(0.0,245.9,109.1) translate(245.9, 109.1)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
#A lot of rehashing of the same code

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circle(radius):
    arc(radius,  360)


#Comparing how refatoring makes everything much more compact in the workflow

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def triangle():
    """This is a simple function to create a preset triangle"""
    for i in range(3):
        forward(50)
        left(120)


make_turtle()
triangle()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.
    
    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
def rectangle(height, width):
    """
    This is a function to create a rectangle which requires 'height' and 'width'
    Make sure at least one of your inputs is greater than the other or else you'd just make a square
    """
    for i in range(2):
        forward(width)
        left(90)
        forward(height)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(40, 80)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):
    """This is a function for a rhombus"""
    for i in range(2):
        forward(length)
        left(angle)
        forward(length)
        left(angle*2)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(20, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="170.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="75.0" x2="180.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="57.7" x2="160.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="57.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
def parallelogram(height, width, angle):
    """This should be able to generalize making parallelograms"""
    for i in range (2):
        forward(width)
        left(angle)
        forward(height)
        left(180 - angle) # I had angle*2 before because it worked for rhombus, but it didn't work when I tried to use this to create a rectangle, so I had chat help me out
        #to get 180 - angle

# %%
def rectangle(height, width):
    """Creates a rectangle using the parallelogram refactoring function"""
    parallelogram(height, width, 90)

make_turtle()
rectangle(50, 25)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="175.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="75.0" x2="175.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def rhombus(height, width, angle):
    """Creates a rhombus with the refactoring"""
    parallelogram(height, width, angle)

make_turtle()
rhombus(50, 30, 45)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="215.4" y2="39.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.4" y1="39.6" x2="185.4" y2="39.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.4" y1="39.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
#I already made one before, but to refactorize i'll make a new one
def triangle(length, angle):
    """Will draw a triangle given the length and angle of it"""
    forward(length)
    left(180-angle)
    forward(length)
    left(180-angle)
    forward(length)

# %%
def draw_pie(n, length):
    angle = 360 / n
    for i in range(n):
        triangle(length, angle)
        left(angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle()
draw_pie(5, 50)
"""
This looks cool but I don't think it's what the question really wants
"""
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="184.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.5" y1="27.4" x2="144.1" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.1" y1="56.8" x2="159.5" y2="104.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.5" y1="104.4" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="159.5" y2="45.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.5" y1="45.6" x2="119.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.1" y1="75.0" x2="159.5" y2="104.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.5" y1="104.4" x2="175.0" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="56.8" x2="134.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.5" y1="27.4" x2="119.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.1" y1="75.0" x2="169.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.1" y1="75.0" x2="184.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.5" y1="27.4" x2="134.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.5" y1="27.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# "\nThis looks cool but I don't think it's what the question really wants\n"

# %%
make_turtle()
draw_pie(7, 40)

"""
This is more like it,

So the n matters for the angle and all that
"""
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="165.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.1" y1="43.7" x2="156.2" y2="82.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.2" y1="82.7" x2="181.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.1" y1="114.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="154.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.0" y1="92.4" x2="145.1" y2="131.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="131.4" x2="181.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.1" y1="114.0" x2="145.1" y2="96.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="96.6" x2="109.0" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="114.0" x2="145.1" y2="131.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="131.4" x2="136.2" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.2" y1="92.4" x2="100.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.1" y1="75.0" x2="109.0" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="114.0" x2="134.0" y2="82.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="82.7" x2="125.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.1" y1="43.7" x2="100.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.1" y1="75.0" x2="140.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.1" y1="75.0" x2="165.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.1" y1="43.7" x2="125.1" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.1" y1="43.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# '\nThis is more like it,\n\nSo the n matters for the angle and all that\n'

# %%
def draw_square(turtle_obj, size = 100):
    for _ in range(4):
        turtle_obj.forward(size)
        turtle_obj.left(90)

def draw_spiral(t):
    """
    draw one square, turn an angle, then draw another square and so on
    """
    for i in range(36):
        draw_square(t, 50)
        t.left(10)

def main():
    t = turtle.Turtle()
    t.speed(0)
    draw_spiral(t)
    turtle.mainloop()

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
def petal(radius, angle):
    arc(radius, angle)
    right(180-angle)
    arc(radius, angle)
    right(180-angle)

make_turtle(delay=0.005)
petal(60, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="152.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.1" y1="75.0" x2="154.2" y2="75.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="75.1" x2="156.3" y2="75.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.2" x2="158.4" y2="75.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="75.4" x2="160.4" y2="75.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="75.7" x2="162.5" y2="76.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.5" y1="76.1" x2="164.5" y2="76.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.5" y1="76.5" x2="166.6" y2="77.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.6" y1="77.0" x2="168.6" y2="77.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.6" y1="77.6" x2="170.6" y2="78.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.6" y1="78.3" x2="172.6" y2="79.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.6" y1="79.0" x2="174.5" y2="79.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.5" y1="79.8" x2="176.4" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.4" y1="80.6" x2="178.3" y2="81.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.3" y1="81.5" x2="180.1" y2="82.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="82.5" x2="182.0" y2="83.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.0" y1="83.6" x2="183.7" y2="84.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.7" y1="84.7" x2="185.5" y2="85.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="85.8" x2="187.2" y2="87.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.2" y1="87.1" x2="188.8" y2="88.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.8" y1="88.4" x2="190.4" y2="89.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="89.7" x2="192.0" y2="91.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="91.1" x2="193.5" y2="92.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.5" y1="92.6" x2="194.9" y2="94.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.9" y1="94.1" x2="196.3" y2="95.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="95.6" x2="197.7" y2="97.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="97.2" x2="199.0" y2="98.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.0" y1="98.9" x2="200.2" y2="100.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="100.6" x2="201.4" y2="102.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="102.3" x2="202.5" y2="104.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="104.1" x2="200.4" y2="104.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="104.1" x2="198.3" y2="104.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.3" y1="104.0" x2="196.2" y2="103.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.2" y1="103.9" x2="194.1" y2="103.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.1" y1="103.7" x2="192.0" y2="103.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="103.4" x2="190.0" y2="103.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="103.0" x2="187.9" y2="102.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.9" y1="102.6" x2="185.9" y2="102.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.9" y1="102.1" x2="183.9" y2="101.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.9" y1="101.5" x2="181.9" y2="100.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.9" y1="100.8" x2="179.9" y2="100.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.9" y1="100.1" x2="178.0" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.0" y1="99.3" x2="176.1" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.1" y1="98.5" x2="174.2" y2="97.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.2" y1="97.6" x2="172.3" y2="96.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.3" y1="96.6" x2="170.5" y2="95.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.5" y1="95.5" x2="168.8" y2="94.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="94.4" x2="167.0" y2="93.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="93.2" x2="165.3" y2="92.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.3" y1="92.0" x2="163.7" y2="90.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.7" y1="90.7" x2="162.1" y2="89.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="89.4" x2="160.5" y2="88.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.5" y1="88.0" x2="159.0" y2="86.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="86.5" x2="157.5" y2="85.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="85.0" x2="156.1" y2="83.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.1" y1="83.5" x2="154.8" y2="81.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.8" y1="81.9" x2="153.5" y2="80.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="80.2" x2="152.3" y2="78.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.3" y1="78.5" x2="151.1" y2="76.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.1" y1="76.8" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def flower(n, radius, angle):
    """Makes a flower
    n = number of petals"""
    for i in range(n):
        petal(radius, angle)
        left(360/n)

make_turtle(delay = 0.005)
flower(10, 50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.7" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.7" y1="75.0" x2="153.5" y2="75.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="75.1" x2="155.2" y2="75.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.2" y1="75.2" x2="157.0" y2="75.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="75.4" x2="158.7" y2="75.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.7" y1="75.6" x2="160.4" y2="75.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.4" y1="75.9" x2="162.1" y2="76.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.1" y1="76.3" x2="163.8" y2="76.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.8" y1="76.7" x2="165.5" y2="77.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.5" y1="77.2" x2="167.2" y2="77.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.2" y1="77.7" x2="168.8" y2="78.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="78.3" x2="170.4" y2="79.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.4" y1="79.0" x2="172.0" y2="79.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.0" y1="79.7" x2="173.6" y2="80.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.6" y1="80.4" x2="175.1" y2="81.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.1" y1="81.3" x2="176.6" y2="82.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.6" y1="82.1" x2="178.1" y2="83.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.1" y1="83.1" x2="179.6" y2="84.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.6" y1="84.0" x2="181.0" y2="85.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.0" y1="85.1" x2="182.3" y2="86.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.3" y1="86.1" x2="183.7" y2="87.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.7" y1="87.3" x2="185.0" y2="88.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="88.4" x2="186.2" y2="89.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.2" y1="89.6" x2="187.4" y2="90.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.4" y1="90.9" x2="188.6" y2="92.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.6" y1="92.2" x2="189.7" y2="93.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.7" y1="93.5" x2="190.8" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.8" y1="94.9" x2="191.8" y2="96.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.8" y1="96.3" x2="192.8" y2="97.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.8" y1="97.8" x2="193.7" y2="99.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.7" y1="99.2" x2="192.0" y2="99.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="99.2" x2="190.2" y2="99.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.2" y1="99.2" x2="188.5" y2="99.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.5" y1="99.1" x2="186.8" y2="98.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.8" y1="98.9" x2="185.0" y2="98.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.0" y1="98.6" x2="183.3" y2="98.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.3" y1="98.3" x2="181.6" y2="98.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.6" y1="98.0" x2="179.9" y2="97.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.9" y1="97.5" x2="178.2" y2="97.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.2" y1="97.1" x2="176.6" y2="96.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.6" y1="96.5" x2="174.9" y2="95.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.9" y1="95.9" x2="173.3" y2="95.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="95.3" x2="171.7" y2="94.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.7" y1="94.6" x2="170.2" y2="93.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.2" y1="93.8" x2="168.6" y2="93.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.6" y1="93.0" x2="167.1" y2="92.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.1" y1="92.1" x2="165.6" y2="91.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.6" y1="91.2" x2="164.2" y2="90.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="90.2" x2="162.8" y2="89.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.8" y1="89.2" x2="161.4" y2="88.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="88.1" x2="160.1" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.1" y1="87.0" x2="158.8" y2="85.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="85.8" x2="157.5" y2="84.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="84.6" x2="156.3" y2="83.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="83.3" x2="155.1" y2="82.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.1" y1="82.1" x2="154.0" y2="80.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.0" y1="80.7" x2="152.9" y2="79.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="79.3" x2="151.9" y2="77.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="77.9" x2="150.9" y2="76.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.9" y1="76.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="151.4" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="74.0" x2="152.9" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="73.0" x2="154.3" y2="72.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.3" y1="72.1" x2="155.9" y2="71.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.9" y1="71.2" x2="157.4" y2="70.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.4" y1="70.4" x2="159.0" y2="69.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="69.6" x2="160.6" y2="68.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.6" y1="68.9" x2="162.2" y2="68.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.2" y1="68.3" x2="163.8" y2="67.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.8" y1="67.7" x2="165.5" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.5" y1="67.1" x2="167.2" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.2" y1="66.6" x2="168.8" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="66.2" x2="170.6" y2="65.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.6" y1="65.8" x2="172.3" y2="65.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.3" y1="65.5" x2="174.0" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.0" y1="65.3" x2="175.7" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.7" y1="65.1" x2="177.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="65.0" x2="179.2" y2="64.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.2" y1="64.9" x2="181.0" y2="64.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.0" y1="64.9" x2="182.7" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.7" y1="65.0" x2="184.5" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.5" y1="65.1" x2="186.2" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.2" y1="65.3" x2="187.9" y2="65.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.9" y1="65.5" x2="189.6" y2="65.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.6" y1="65.8" x2="191.3" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.3" y1="66.2" x2="193.0" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.0" y1="66.6" x2="194.7" y2="67.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.7" y1="67.1" x2="196.4" y2="67.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.4" y1="67.7" x2="198.0" y2="68.3"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
